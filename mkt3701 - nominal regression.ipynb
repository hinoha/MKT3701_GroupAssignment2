# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import numpy.random as rd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from scipy import stats

data = pd.read_csv("HomworkData.csv")                # Read the dataset
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0013-EXCHZ  Female              1     Yes         No       3          Yes
# 1  0020-INWCK  Female              0     Yes        Yes      71          Yes
# 2  0104-PPXDV    Male              0     Yes         No      58          Yes
# 3  0107-WESLM    Male              0      No         No       1          Yes
# 4  0112-QAWRZ    Male              0     Yes        Yes      16          Yes
# 5  0137-OCGAB  Female              0      No         No       1          Yes
# 6  0164-XAIRP  Female              0      No         No      24          Yes
# 7  0187-QSXOE    Male              1     Yes         No       7          Yes
# 8  0201-MIBOL  Female              1      No         No      66          Yes
# 9  0214-JHPFW  Female              0     Yes         No      70           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %%
churn_binary = {"Churn": {"Yes":1, "No":0}}
data.replace(churn_binary, inplace=True)

techsupport_dummy = pd.get_dummies(data, columns=["TechSupport"])
pd.get_dummies(data, columns=["TechSupport"]).head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0013-EXCHZ  Female              1     Yes         No       3          Yes
# 1  0020-INWCK  Female              0     Yes        Yes      71          Yes
# 2  0104-PPXDV    Male              0     Yes         No      58          Yes
# 3  0107-WESLM    Male              0      No         No       1          Yes
# 4  0112-QAWRZ    Male              0     Yes        Yes      16          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No     Fiber optic                   No  ...
# 1           Yes     Fiber optic                   No  ...
# 2            No             DSL                   No  ...
# 3            No              No  No internet service  ...
# 4           Yes     Fiber optic                   No  ...
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No  Month-to-month              Yes
# ...

# %%
data = pd.concat([techsupport_dummy],axis=1)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  0013-EXCHZ  Female              1     Yes         No       3          Yes
# 1  0020-INWCK  Female              0     Yes        Yes      71          Yes
# 2  0104-PPXDV    Male              0     Yes         No      58          Yes
# 3  0107-WESLM    Male              0      No         No       1          Yes
# 4  0112-QAWRZ    Male              0     Yes        Yes      16          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No     Fiber optic                   No  ...
# 1           Yes     Fiber optic                   No  ...
# 2            No             DSL                   No  ...
# 3            No              No  No internet service  ...
# 4           Yes     Fiber optic                   No  ...
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No  Month-to-month              Yes
# ...

# %%
X = data[data.columns[-3::]]
Y = data["Churn"]

print(X)
print(Y)
# Out:
#      TechSupport_No  TechSupport_No internet service  TechSupport_Yes
# 0                 0                                0                1
# 1                 1                                0                0
# 2                 1                                0                0
# 3                 0                                1                0
# 4                 1                                0                0
# ..              ...                              ...              ...
# 490               0                                1                0
# 491               0                                1                0
# 492               0                                1                0
# 493               0                                0                1
# 494               1                                0                0
#
# [495 rows x 3 columns]
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 490    0
# 491    0
# 492    0
# ...

# %%
import statsmodels.api as sm
logit_model=sm.Logit(Y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.507850
#          Iterations 7
#                                 Results: Logit
# ...
# Model:                    Logit                Pseudo R-squared:     0.111
# Dependent Variable:       Churn                AIC:                  508.7713
# Date:                     2020-04-04 19:34     BIC:                  521.3850
# No. Observations:         495                  Log-Likelihood:       -251.39
# Df Model:                 2                    LL-Null:              -282.93
# Df Residuals:             492                  LLR p-value:          2.0006e-14
# Converged:                1.0000               Scale:                1.0000
# No. Iterations:           7.0000
# -------------------------------------------------------------------------------
#                                  Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -------------------------------------------------------------------------------
# ...
